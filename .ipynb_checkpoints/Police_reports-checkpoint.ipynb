# %%
import pandas as pd
dfjson = pd.read_json ('https://data.medicare.gov/data.json')
dfjson
# Out:
#                                               @context  \
# 0    https://project-open-data.cio.gov/v1.1/schema/...
# 1    https://project-open-data.cio.gov/v1.1/schema/...
# 2    https://project-open-data.cio.gov/v1.1/schema/...
# 3    https://project-open-data.cio.gov/v1.1/schema/...
# 4    https://project-open-data.cio.gov/v1.1/schema/...
# ..                                                 ...
# 137  https://project-open-data.cio.gov/v1.1/schema/...
# 138  https://project-open-data.cio.gov/v1.1/schema/...
# 139  https://project-open-data.cio.gov/v1.1/schema/...
# 140  https://project-open-data.cio.gov/v1.1/schema/...
# 141  https://project-open-data.cio.gov/v1.1/schema/...
#
#                                      @id         @type  \
# 0    https://data.medicare.gov/data.json  dcat:Catalog
# 1    https://data.medicare.gov/data.json  dcat:Catalog
# 2    https://data.medicare.gov/data.json  dcat:Catalog
# 3    https://data.medicare.gov/data.json  dcat:Catalog
# ...

# %%
dfcsv = pd.read_csv('/Users/robholmstrom/Downloads/Police_Incidents.csv')
dfcsv
# Out:
# /Users/robholmstrom/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (52,57,60,64,74) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Incident Number w/year  Year of Incident Service Number ID  Watch  \
# 0                 027044-2020              2020    027044-2020-01      3
# 1                 215716-2019              2019    215716-2019-01      2
# 2                 032879-2015              2015    032879-2015-01      1
# 3                 008835-2015              2015    008835-2015-01      1
# 4                 063689-2015              2015    063689-2015-01      1
# ...                       ...               ...               ...    ...
# 418383            097354-2019              2019    097354-2019-01      2
# 418384            067907-2017              2017    067907-2017-01      3
# ...

# %%
dfcsv.info()
dfdrop = dfcsv.drop(['Victim Business Phone','Special Report (Pre-RMS)', 'Victim Business Phone'],axis =1 )
dfdrop
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418388 entries, 0 to 418387
# Data columns (total 100 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Incident Number w/year                     418388 non-null  object
#  1   Year of Incident                           418388 non-null  int64
#  2   Service Number ID                          418388 non-null  object
#  3   Watch                                      418388 non-null  int64
#  4   Call (911) Problem                         403544 non-null  object
#  5   Type of Incident                           418388 non-null  object
#  6   Type  Location                             417898 non-null  object
#  7   Type of Property                           90210 non-null   object
#  8   Incident Address                           417637 non-null  object
# ...

# %%
df = pd.read_csv('/Users/robholmstrom/Downloads/drugsCom_raw/drugsComTrain_raw.tsv', sep='\t')

# %%
df
# Out:
#         Unnamed: 0                  drugName                     condition  \
# 0           206461                 Valsartan  Left Ventricular Dysfunction
# 1            95260                Guanfacine                          ADHD
# 2            92703                    Lybrel                 Birth Control
# 3           138000                Ortho Evra                 Birth Control
# 4            35696  Buprenorphine / naloxone             Opiate Dependence
# ...            ...                       ...                           ...
# 161292      191035                   Campral            Alcohol Dependence
# 161293      127085            Metoclopramide               Nausea/Vomiting
# 161294      187382                   Orencia          Rheumatoid Arthritis
# 161295       47128        Thyroid desiccated           Underactive Thyroid
# 161296      215220              Lubiprostone         Constipation, Chronic
#
#                                                    review  rating  \
# ...
