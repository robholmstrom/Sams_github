# %%
import json
from datetime import datetime
import plotly.express as px
from sklearn.model_selection import train_test_split
import sqlite3
import nltk
import spacy
import geopandas as gpd
from shapely.geometry import Polygon
import numpy as np
import umap
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
# %matplotlib inline

# %%
df_business_last_4yrs = pd.read_csv('/Users/robholmstrom/OneDrive/Gitrepos/nonrepo_files/capstone4_files/df_business_last_4yrs_open.csv')

# %%
df_reviews_4yrs = pd.read_csv('/Users/robholmstrom/OneDrive/Gitrepos/nonrepo_files/capstone4_files/df_reviews_last_4yrs_open.csv')
# Out:
# /Users/robholmstrom/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_reviews_4yrs['stars'] = df_reviews_4yrs['stars'].values.tolist() # = df_reviews_4yrs['stars'].astype(int)

# %%
df_reviews_4yrs['stars'].value_counts()
# Out:
# 5.0    2229116
# 1.0     790052
# 4.0     749358
# 3.0     380970
# 2.0     315129
# Name: stars, dtype: int64

# %%
df_reviews_4yrs_mean = pd.DataFrame(df_reviews_4yrs.groupby('business_id')['stars'].mean())

# %%
df_business_last_4yrs['is_open'].value_counts()
# Out:
# 1    163300
# Name: is_open, dtype: int64

# %%
df_business_rev = df_business_last_4yrs.merge(df_reviews_4yrs_mean, on='business_id').drop('stars_x', axis=1)
df_business_rev['stars_avg'] = df_business_rev['stars_y'].round(0).astype(int)

# %%
df_business_last_4yrs = df_business_last_4yrs.loc[df_business_last_4yrs['is_open']==1]

# %%
df_business_rev_v2 = df_business_rev.drop(['attributes', 'stars_y','hours'], axis= 1)

# %%
plt.bar(df_business_rev_v2['stars_avg'].unique(), height = df_business_rev_v2['stars_avg'].value_counts())
plt.ylabel('Frequency', fontsize = 10)  
plt.xlabel('Stars', fontsize = 10)  
plt.title(label = 'Star frequency', fontsize=20)
plt.show()

# %%
df_bus_rev_select =  df_business_rev_v2[df_business_rev_v2['review_count']>1]
df_bus_rev_select.shape
# Out:
# (163300, 13)

# %%
plt.figure(figsize = (15, 5))
plt.plot(df_bus_rev_select['state'].value_counts())
plt.xlabel('States', fontsize = 15)  
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel('Number of reviews', fontsize = 15)  
plt.title(label = 'Reviews by State/Province', fontsize=30)
plt.show()

# %%
threshold = 0.1
review_by_state = pd.DataFrame(df_bus_rev_select['state'].value_counts())
states_select = review_by_state[review_by_state['state'] > threshold*review_by_state.max()['state']]
states_select
# Out:
#     state
# AZ  48196
# NV  30364
# ON  27059
# OH  13431
# NC  13113
# PA   9968
# QC   7875
# AB   6323

# %%
df_bus_rev_select = df_bus_rev_select.loc[df_bus_rev_select['state'].isin(states_select.index)==True]

# %%
df_bus_rev_select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156329 entries, 0 to 163299
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    156329 non-null  int64
#  1   business_id   156329 non-null  object
#  2   name          156329 non-null  object
#  3   address       149113 non-null  object
#  4   city          156327 non-null  object
#  5   state         156329 non-null  object
#  6   postal_code   155974 non-null  object
#  7   latitude      156329 non-null  float64
#  8   longitude     156329 non-null  float64
#  9   review_count  156329 non-null  int64
#  10  is_open       156329 non-null  int64
#  11  categories    155877 non-null  object
#  12  stars_avg     156329 non-null  int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 16.7+ MB

# %%
df_food_bus = df_bus_rev_select[df_bus_rev_select['categories'].str.contains('Restaurant')|
                 df_bus_rev_select['categories'].str.contains('Coffee & Tea')]

# %%
df_food = df_food_bus.copy()
catlist_clean = df_food['categories'].str.replace(' ', '' ).str.replace(',', ', ')

# %%
df_food['categories_filtered']= catlist_clean

# %%
food_categories = pd.read_csv('/Users/robholmstrom/OneDrive/Gitrepos/nonrepo_files/Yelp_food_categories.csv')
food_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Categories   0 non-null      float64
#  1   Food_types   69 non-null     object
#  2   Ethnicities  96 non-null     object
#  3   Venue_type   51 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 6.9+ KB

# %%
food_types = food_categories['Food_types'].dropna().str.strip().str.replace(' ', '')
ethnicities = food_categories['Ethnicities'].dropna().str.strip().str.replace(' ', '')
venue_types = food_categories['Venue_type'].dropna().str.strip().str.replace(' ', '')

# %%
type_list = []

for x in df_food['categories_filtered']:
    sublist = []
    for i in food_types:
        if i in x:
            sublist.append(i)
    
    if len(sublist) == 0:
        type_list.append(['Undefined'])
    else:
        type_list.append(sublist)  

print(len(type_list))
print(df_food.shape[0])
# Out:
# 44380
# 44380

# %%
venue_list = []

for x in  df_food['categories_filtered']:
    sublist = []
    for i in venue_types:
        if i in x:
            sublist.append(i)
    
    if len(sublist) == 0:
        venue_list.append(['Restaurant'])
    else:
        venue_list.append(sublist)  

print(len(venue_list))
print(df_food.shape[0])
# Out:
# 44380
# 44380

# %%
ethnicity_list = []

for x in  df_food['categories_filtered']:
    sublist = []
    for i in ethnicities:
        if i in x:
            sublist.append(i)
    
    if len(sublist) == 0:
        ethnicity_list.append(['Undefined'])
    else:
        ethnicity_list.append(sublist)  
print(len(ethnicity_list))
print(df_food.shape[0])
# Out:
# 44380
# 44380

# %%
df_food['food_type'] = type_list
df_food['ethnicity'] = ethnicity_list
df_food['venue'] = venue_list

# %%
df_food['food_comb'] = (df_food['food_type']+df_food['ethnicity']+df_food['venue']).apply(lambda x: ', '.join(x))
df_food['food_comb'] = df_food['food_comb'].str.replace('Undefined,', '')

# %%
df_food_clean = df_food.drop(columns = ['categories'])
df_food_clean['food_type'] = df_food_clean['food_type'].apply(lambda x: ', '.join(x))
df_food_clean['venue'] = df_food_clean['venue'].apply(lambda x: ', '.join(x))
df_food_clean['ethnicity']= df_food_clean['ethnicity'].apply(lambda x: ', '.join(x))

# %%
(df_food_clean['postal_code']=='').value_counts()
# Out:
# False    44380
# Name: postal_code, dtype: int64

# %%
df_food_clean['postal_code'].replace('', np.nan, inplace = True)
df_food_clean.dropna(inplace = True)

# %%
df_food_clean.reset_index(drop=True, inplace= True)

# %%
df_food_clean
# Out:
#        Unnamed: 0             business_id  \
# 0              24  eBEfgOPG7pvFhb2wcG9I7w
# 1              25  lu7vtrp_bE9PnxWfA8g4Pg
# 2              30  9sRGfSVEfLhN_km60YruTA
# 3              33  vjTVxnsQEZ34XjYNS-XUpA
# 4              41  98hyK2QEUeI8v2y0AghfZA
# ...           ...                     ...
# 44014      209376  cmsAFAymfVoBitSF8R6GKw
# 44015      209377  n2BKYb8aw4AhRKLkdUjQRg
# 44016      209380  YZeUH6zYS0dq5QHLYZhUnQ
# 44017      209385  hskVqZCPqy-omm9CHi44xQ
# 44018      209390  SYa2j1boLF8DcGVOYfHPcA
#
#                                          name  \
# 0                             Philthy Phillys
# 1                                Banzai Sushi
# 2                          Apadana Restaurant
# 3                           Wetzel's Pretzels
# 4             Pho Lee's Vietnamese Restaurant
# ...                                       ...
# 44014                Yao Fine Chinese Cuisine
# 44015  Steak & Cheese & Quick Pita Restaurant
# 44016                                 Hooters
# 44017                                Domino's
# 44018                               Five Guys
#
#                                 address           city state postal_code  \
# 0      15480 Bayview Avenue, unit D0110         Aurora    ON     L4G 7J1
# 1                       300 John Street      Thornhill    ON     L3T 5W4
# 2                    13071 Yonge Street  Richmond Hill    ON     L4E 1A5
# 3          4550 East Cactus Rd, #KSFC-4        Phoenix    AZ       85032
# 4               1541 E 38th St, Ste 101      Cleveland    OH       44114
# ...                                 ...            ...   ...         ...
# 44014        2487 S Gilbert Rd, Ste 102        Gilbert    AZ       85295
# 44015                    199 College St        Toronto    ON     M5T 1P9
# 44016                   2820 N 75th Ave        Phoenix    AZ       85035
# 44017             6420 Rea Rd, Suite B1      Charlotte    NC       28226
# 44018           7014-590 E Camelback Rd     Scottsdale    AZ       85251
#
#         latitude   longitude  review_count  is_open  stars_avg  \
# 0      44.010962  -79.448677             4        1          4
# 1      43.820492  -79.398466             7        1          5
# 2      43.947011  -79.454862             3        1          3
# 3      33.602822 -111.983533            10        1          3
# 4      41.512155  -81.663332            23        1          4
# ...          ...         ...           ...      ...        ...
# 44014  33.304935 -111.788861           230        1          4
# 44015  43.658683  -79.395071            21        1          3
# 44016  33.479139 -112.221142           106        1          2
# 44017  35.078538  -80.818358            16        1          1
# 44018  33.504062 -111.929431            97        1          3
#
#                                      categories_filtered  \
# 0                 Restaurants, Cheesesteaks, Poutineries
# 1             Japanese, FastFood, FoodCourt, Restaurants
# 2      Persian/Iranian, Turkish, MiddleEastern, Resta...
# 3        Food, Pretzels, Bakeries, FastFood, Restaurants
# 4                          Restaurants, Vietnamese, Soup
# ...                                                  ...
# 44014                               Chinese, Restaurants
# 44015                            Sandwiches, Restaurants
# 44016  Nightlife, American(Traditional), ChickenWings...
# 44017  Restaurants, Pizza, Sandwiches, FastFood, Chic...
# 44018  American(New), Food, Burgers, Restaurants, Fas...
#
#                                        food_type  \
# 0                      Cheesesteaks, Poutineries
# 1                                       FastFood
# 2                                          Kebab
# 3                   Bakeries, Pretzels, FastFood
# 4                                           Soup
# ...                                          ...
# 44014                                  Undefined
# 44015                                 Sandwiches
# 44016                               ChickenWings
# 44017  ChickenWings, FastFood, Pizza, Sandwiches
# 44018                          Burgers, FastFood
#
#                                      ethnicity       venue  \
# 0                                    Undefined  Restaurant
# 1                                     Japanese   FoodCourt
# 2      MiddleEastern, Persian/Iranian, Turkish  Restaurant
# 3                                    Undefined  Restaurant
# 4                                   Vietnamese  Restaurant
# ...                                        ...         ...
# 44014                                  Chinese  Restaurant
# 44015                                Undefined  Restaurant
# 44016                    American(Traditional)  Restaurant
# 44017                                Undefined  Restaurant
# 44018                            American(New)  Restaurant
#
#                                                food_comb
# 0                 Cheesesteaks, Poutineries,  Restaurant
# 1                          FastFood, Japanese, FoodCourt
# 2      Kebab, MiddleEastern, Persian/Iranian, Turkish...
# 3              Bakeries, Pretzels, FastFood,  Restaurant
# 4                           Soup, Vietnamese, Restaurant
# ...                                                  ...
# 44014                                Chinese, Restaurant
# 44015                            Sandwiches,  Restaurant
# 44016    ChickenWings, American(Traditional), Restaurant
# 44017  ChickenWings, FastFood, Pizza, Sandwiches,  Re...
# 44018       Burgers, FastFood, American(New), Restaurant
#
# [44019 rows x 17 columns]

# %%
df_food_clean.to_csv('/Users/robholmstrom/OneDrive/Gitrepos/nonrepo_files/capstone4_files/df_food_clean.csv')
