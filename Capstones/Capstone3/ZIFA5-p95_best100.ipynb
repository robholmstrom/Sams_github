# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import numpy as np
import umap
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.mixture import GaussianMixture
from sklearn.feature_selection import SelectKBest, f_classif
import pylab
import scipy
import sklearn
import time
import seaborn as sns
from mpl_toolkits import mplot3d 
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px

# %%
pd.set_option("display.max_rows", 250000)

# %%
df = pd.read_csv('/Users/robholmstrom/OneDrive/Gitrepos/nonrepo_files/GSE59114.csv', header = 1)
df1 = df.T
df1.columns = df1.loc['Gene Symbol'].reset_index()
df1 = df1.drop(['Gene Symbol', 'UCSC transcripts'])
df1.columns = [x[1] for x in df1.columns]
df1.columns = df1.columns.str.replace("'", "")
df1.shape
# Out:
# (1434, 8422)

# %% [markdown]
# Itgam, Ly6g, Ptprc, Cd3e, Ly76, Kit, Ly6a, Cd48, Slamf1

# %%
import re
df1_1 = df1[~df1.index.str.contains('biol_replicate')]
df1_1 = df1_1.drop(['\'Young LT-HSC\'','\'Young ST-HSC\'', '\'Young MPP\'','\'Old LT-HSC\'', '\'Old ST-HSC\'','Old MPP\''])
df1_1 = df1_1.drop(['Itgam', 'Ptprc', 'Kit', 'Ly6a', 'Cd48', 'Slamf1'], axis = 1)

# %%
df1_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1058 entries, young_LT_HSC_2 to old_MPP_168
# Columns: 8416 entries, Npl to Sft2d1
# dtypes: object(8416)
# memory usage: 67.9+ MB

# %%
df1_1.index = df1_1.index.str.replace(r'[^a-zA-Z]', '')

print((df1_1.columns).shape)
print(np.unique(df1_1.columns).shape)
# Out:
# (8416,)
# (8351,)

# %%
df1_1dup = df1_1[df1_1.loc[:,df1_1.columns.duplicated()].columns]

# %%
dupcols = np.unique(df1_1dup.columns)
dupcols
# Out:
# array(['Abcg2', 'Arih1', 'Atf7ip', 'Atrip', 'Brwd1', 'Cbx1', 'Ccnd3',
#        'Cdk6', 'Celf1', 'Commd1', 'Csnk1a1', 'Ctse', 'Dnajb6', 'Eci2',
#        'Eif1ax', 'Fgd4', 'Fus', 'G3bp1', 'Glod4', 'Gm10598', 'Gm13215',
#        'Hjurp', 'Ikbkb', 'Ing4', 'Itga4', 'Itga6', 'Kansl2', 'Lcor',
#        'Lrrc29', 'Luc7l2', 'Mafg', 'Mecom', 'Mob1a', 'Mtcp1', 'Nagk',
#        'Ndufa3', 'Pafah1b1', 'Patz1', 'Pcif1', 'Pik3ip1', 'Psme4', 'Pten',
#        'Ramp2', 'Rpl24', 'Rspry1', 'Satb1', 'Smarcc2', 'Srcap', 'Srsf10',
#        'Sugp2', 'Taf9', 'Tex261', 'Tmem167b', 'Tmem181b-ps', 'Trappc9',
#        'Trim30b', 'U2af1l4', 'Utp23', 'Wwp2', 'Zbtb20', 'Zfp708',
#        'Zfp869', 'Zgpat'], dtype=object)

# %%
df1_1dupgroup = df1_1dup.groupby(df1_1dup.columns, axis=1).sum()

# %%
df1_1dupmean = pd.DataFrame()
for x in dupcols:
    df1_1dupmean[x] = df1_1dupgroup[x]/df1_1dup.columns.tolist().count(x)

# %%
# cols = []
# n = 1
# for x in df2dup.columns:
#     if x in cols:
#         cols.append(x+'.'+str(n))
#         n += 1
#     else:
#         cols.append(x)
#         n = 1

# %%
dfnodup = df1_1.loc[:,~df1_1.columns.duplicated()].drop(dupcols, axis = 1)

df2 = pd.concat([dfnodup, df1_1dupmean], axis = 1).astype(np.float64)

df2= df2.round(2)
df2.shape
# Out:
# (1058, 8351)

# %%
y = [x for x in df2.index]

k = 100
kbest = SelectKBest(k=k, score_func=f_classif)
X_best_feat = kbest.fit_transform(df2,y)

X_best_feat = pd.DataFrame(X_best_feat, columns=df2.columns[kbest.get_support()])

trimcol = X_best_feat.columns
trimcol
# Out:
# Index(['Wtap', 'Rab44', 'H2-K1', 'H2-D1', 'Tubb5', 'Sell', 'Selp', 'Bin1',
#        'Malat1', 'Gda', 'uc008hln.1', 'Dntt', 'Pdcd4', 'C330006A16Rik',
#        'Lrrc8a', 'Cd34', 'Atp8b4', 'uc008muc.2', 'Tgm2', 'Serinc3', 'Car2',
#        'Slc39a1', 'Cd53', 'Clca1', 'Mllt3', 'Ptplad2', 'Pdzk1ip1', 'Mpl',
#        'Gm12940', 'Ptp4a2', 'Cd52', 'Ccdc21', 'Gnb1', 'Gatad1', 'Plac8',
#        'Gm10419', 'Arpc3', 'Lat2', 'Flt3', 'Cbx3', 'Mmrn1', 'Tmsb10', 'Vwf',
#        'BC035044', 'Clec1a', 'Apoe', 'Gmfg', 'uc009fzz.2,uc009gaa.2', 'Tyrobp',
#        'Nkg7', 'Ftl1', 'Klf13', 'Hbb-b1', 'Nupr1', 'Sult1a1', 'Arglu1', 'Mt1',
#        'Gpr97', 'Sdpr', 'Rpl13', 'uc009nvu.1', 'uc009nvv.1', 'Ppm1h', 'Plscr2',
#        'Trf', 'mt-Rnr1', 'uc012hdk.1', 'mt-Co1', 'Ptges3', 'Tespa1',
#        'uc007hxv.1', 'Ppia', 'Hba-a1', 'Hba-a2', 'Pfas', 'Spns3', 'Ccl9',
#        'Wfdc17', 'Mpo', 'Eif1', 'Ptrf', 'Srsf2', 'Acot2', 'Fos', 'Ptma',
#        'Ighv1-30', 'Zfp187', 'Serpinb1a', 'Ramp1', 'H2afy', 'Plk2', 'Emb',
#        'Sept2', 'Rpgrip1', 'Clu', 'Bex6', 'uc007yyn.2', 'Gsk3b', 'Sod1',
#        'Cdk6'],
#       dtype='object')

# %%
genefracs = (df2==0).sum()/(df2==0).count()
passindex = genefracs[genefracs < 0.95]

# %%
zifa = df2[passindex.index]
zifa= np.round(zifa.astype(np.float64),4)
zifa = np.array(zifa)
zifa.shape
# Out:
# (1058, 8240)

# %%
zifabest = df2[trimcol]
zifabest= np.round(zifabest.astype(np.float64),4)
zifabest = np.array(zifabest)
zifabest.shape
# Out:
# (1058, 100)

# %%
from ZIFA import ZIFA
from ZIFA import block_ZIFA

# %%
start_time = time.time()
Zbest, model_params = block_ZIFA.fitModel(zifabest, 5)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Filtering out all genes which are zero in more than 95.0% of samples. To change this, change p0_thresh.
# Warning: your Y matrix contains genes which are frequently zero. If the algorithm fails to converge, try filtering out genes which are zero more than 80 - 90% of the time, or using standard ZIFA.
# Number of blocks has been set to 1
# Running block zero-inflated factor analysis with N = 1058, D = 100, K = 5, n_blocks = 1
# Block sizes [100]
# Param change below threshold 1.000e-02 after 3 iterations
# --- 8.07337498664856 seconds ---

# %%
start_time = time.time()
Z, model_params = block_ZIFA.fitModel(zifa, 5)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Filtering out all genes which are zero in more than 95.0% of samples. To change this, change p0_thresh.
# Warning: your Y matrix contains genes which are frequently zero. If the algorithm fails to converge, try filtering out genes which are zero more than 80 - 90% of the time, or using standard ZIFA.
# Number of blocks has been set to 16
# Running block zero-inflated factor analysis with N = 1058, D = 8240, K = 5, n_blocks = 16
# Block sizes [515, 515, 515, 515, 515, 515, 515, 515, 515, 515, 515, 515, 515, 515, 515, 515]
# Param change below threshold 1.000e-02 after 12 iterations
# --- 1978.2571668624878 seconds ---

# %%
dfz = pd.DataFrame(Z, index = df2.index)
pcaz = PCA(n_components=3, random_state = 42)

zcomps = pcaz.fit_transform(dfz)
sns.scatterplot(zcomps[:,0], zcomps[:,1])
plt.show()

# %%
sns.scatterplot(zcomps[:,0], zcomps[:,1], hue = dfz.index)
plt.show()

# %%
dfzbest = pd.DataFrame(Zbest, index = df2.index)
pcazbest = PCA(n_components=3, random_state = 42)

zcompsbest = pcazbest.fit_transform(dfzbest)
sns.scatterplot(zcompsbest[:,0], zcompsbest[:,1])
plt.show()

# %%
sns.scatterplot(zcompsbest[:,0], zcompsbest[:,1], hue = dfzbest.index)
plt.show()

# %%
encoded = {'oldLTHSC':0, 'oldMPP':1, 'oldSTHSC':2, 'youngLTHSC':3, 'youngMPP':4, 'youngSTHSC':5}
cells = ['oldLTHSC' ,'oldMPP', 'oldSTHSC', 'youngLTHSC' ,'youngMPP' ,'youngSTHSC']
cell_types = [encoded.get(x, x) for x in dfz.index]
colormap = ['r', 'b', 'g', 'y', 'c', 'm']
cell_colors = [colormap[x] for x in cell_types]
dfpca = pd.DataFrame(zcomps, index = dfzbest.index)
dfpca
fig = px.scatter_3d(dfpca, zcomps[:,0], zcomps[:,1],zcomps[:,2], dfpca.index)
fig.update_traces(marker=dict(opacity =1, size=4,
                              line=dict(width= .1)))

fig.show()
# Out:
# <div>
#
#
#             <div id="2dbfc89a-1cad-404a-ab80-b87f6e34182e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2dbfc89a-1cad-404a-ab80-b87f6e34182e")) {
#                     Plotly.newPlot(
#                         '2dbfc89a-1cad-404a-ab80-b87f6e34182e',
#                         [{"hovertemplate": "index=youngLTHSC<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>", "legendgroup": "youngLTHSC", "marker": {"color": "#636efa", "line": {"width": 0.1}, "opacity": 1, "size": 4, "symbol": "circle"}, "mode": "markers", "name": "youngLTHSC", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.7501904365236566, -1.5031349792496869, -0.41760260346145, 0.4203023761813825, 0.5394555257569541, 0.30933752804740106, -1.061486079345341, -0.5963564032236919, -0.845485648323729, 0.8024987086809222, 1.7479438721721132, -0.9861374496097665, -1.3900267712870407, -1.1497819095884207, -0.9168372840967391, 1.3312340444740205, -1.2420595677358242, -0.963521758574127, -0.9309709425364531, -0.40131002867325133, 0.6534870664670449, -0.045481955613231, -0.6822419567490126, 1.99285910427935, 0.7633214253877307, -0.5940118361497644, 1.3586667314392227, 0.8428754142332745, 0.18991072920651308, -1.2947060197409905, 1.3380918330720164, 0.12072672602097176, -0.08669853122859394, -1.4560780816215646, 0.6897656070959283, -0.4939746550490916, -1.437854422015303, 1.4619092359568173, -0.4487051141187809, -0.9955092992316145, -0.6314780276637295, -1.4307803461421271, -1.7876109851098836, -0.8459652128931551, -0.7620690434372731, -0.8247629417937794, -0.4476882472882601, -0.1974463017257025, -0.10361719831111553, -0.515173760927405, 0.2552528810021584, -1.276912947075725, -1.4066947691020073, -1.2123751508268743, -0.18072311690112508, 0.4081957557393631, 2.66173548283095, -1.9425553787144396, 1.1137816191056114, -1.40154255267899, 1.1116321119144659, 0.038177297323483246, -1.8659334050555672, -0.7117224085034706, 0.1579976775963122, -1.663764601137232, -0.5697932093097644, -1.288329013666643, 0.007880782363067015, 1.5140988347879403, -0.5799231422483225, -1.6064383849341004, -1.251565462209318, -0.8303640791040823, -0.5783141096616702, -1.6082454322131017, 1.63179908073224, 1.3741644944229539, -1.1639265086330997, -0.9191150021752351, 0.09487917228893197, 1.0553133796180325, -0.3899303090503116, 0.01926348837955796, -0.8908930322208211, 0.3000492036318871, -1.1297936224482874, -0.44276567755741036, 0.3421931909951966, -0.6567251256831054, 0.43650922361442435, 0.21183958407837722, -0.26492745185764693, -0.9464286485548791, -0.9291508559774916, -0.6073119698984419, -0.9204130903083456, -1.6843179975754685, 1.8179190174230153, -0.32782926141540986, -1.1236456746399883, -0.44615010240107994, -0.498393110415538, -0.4877981962758215, -1.0027770971683212, -1.0811866029224682, -0.20885299302341445, -0.5102784229677225, -0.2548372399463729, -1.3734377130670798, -0.4273263543335531, 2.3998746690302766, 0.5697991802965369, -0.7990574117248919, 0.678854630425543, -1.1790602835026855, -1.698467987425952, 0.7350631339145933, -0.8335362011915385, -1.3552770040538267, -0.4958554818048584, 0.16697611577164825, 0.35571360759442133, -0.5166751549173951, -0.7344812554036323, -0.27349944079774613, -0.7972167502516493, -1.1625052917345706, -1.459793603597042, -0.20978530785476168, 0.7459978371625425, 0.3954992685691289, -0.8489712610726952, -0.3110479486253213, -0.0873514310643022, -1.4788438431095363, -1.1166035325614685, -1.548436523526458, 1.2656444357359304, 0.1013765035606593, -0.36331974718597054, -0.4969848469450142, -0.9277470378334924, -0.3210001376292906, 1.7825437693296728, -1.6167960659763272, -0.6267433143888559, -1.4730124852004123, -1.2802798450029431, 0.6442109539351749, 1.4467907420322081, -0.24494937186320923, -0.8540133488361799, -0.6901084375351096, -1.1758261812195439, -0.22677818038148204, -0.5166651532062716, -0.761316242015543, -1.248700006501469, -0.4472298005476549, 0.5769704471109771, -1.1327516381522467, 0.598641338023684, -1.1869748400071314, -0.8258323547163742, -0.7613012940246281, -1.2662765203283135], "y": [-0.20899546494088803, -0.5879313279412413, -1.681554326224847, -0.36205849094998366, 0.47034226849883226, -0.593096360634267, -1.391962426490089, -1.4477164260312263, 0.4739447178495206, -0.156 ...

# %%
encoded = {'oldLTHSC':0, 'oldMPP':1, 'oldSTHSC':2, 'youngLTHSC':3, 'youngMPP':4, 'youngSTHSC':5}
cells = ['oldLTHSC' ,'oldMPP', 'oldSTHSC', 'youngLTHSC' ,'youngMPP' ,'youngSTHSC']
cell_types = [encoded.get(x, x) for x in dfzbest.index]
colormap = ['r', 'b', 'g', 'y', 'c', 'm']
cell_colors = [colormap[x] for x in cell_types]
dfpcabest = pd.DataFrame(zcompsbest, index = dfzbest.index)
dfpcabest
fig = px.scatter_3d(dfpcabest, zcompsbest[:,0], zcompsbest[:,1],zcompsbest[:,2], dfpcabest.index)
fig.update_traces(marker=dict(opacity =1, size=4,
                              line=dict(width= .1)))

fig.show()
# Out:
# <div>
#
#
#             <div id="e2aa256e-50a3-417b-b2bd-2ce1ad8452da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2aa256e-50a3-417b-b2bd-2ce1ad8452da")) {
#                     Plotly.newPlot(
#                         'e2aa256e-50a3-417b-b2bd-2ce1ad8452da',
#                         [{"hovertemplate": "index=youngLTHSC<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>", "legendgroup": "youngLTHSC", "marker": {"color": "#636efa", "line": {"width": 0.1}, "opacity": 1, "size": 4, "symbol": "circle"}, "mode": "markers", "name": "youngLTHSC", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.2441770206693316, -0.8416132271709871, -0.3240530399480399, -0.7017479892015192, -0.875303401205416, -0.46834842494345647, -0.46484921939059665, 1.9893746833942523, -0.6570456556815318, -0.8260856324877895, -0.7399459160350736, 1.0512046921909517, 0.03029863526346389, -0.34980568098418785, -0.025080785338311703, -0.547648233059273, -0.4655411644519831, -0.11970480944373046, -0.5399120224793733, 1.8985854955841945, -0.44651552986721127, -0.3492922782716637, 0.5911676091181455, -0.4638841661671417, -0.3562968056197222, -0.6697298761071049, -0.38997605238514055, -0.7776141756765425, -0.5354668390518766, -0.36685056056348436, -0.3438685409984509, -0.2285439091658626, -0.2875565900064759, -0.5095230327959932, -0.662474279792435, -0.3937069762474202, -0.5650089472536264, -0.6520240129571472, -0.5864807306078393, -0.46629563914856687, -0.3987099855783389, -0.17814895546397122, -0.6599981980035273, -0.6887931059380862, -0.43912081581826573, -0.1532434126615349, -0.008933667427200948, -0.5028112661356026, -0.1629201137910748, -0.11390015666809758, -0.607999596951375, -0.5060180962707409, -0.18669217496924365, -0.5674282018274069, -0.6151765005862984, -0.2905744740335156, -0.5376220411275825, -0.7126103245809314, 0.11749432451892824, -0.41469189104772425, -0.3291629499133512, -0.15134548877482493, 3.4321628279384444, -0.06150243850730892, -0.3567062243825211, 0.04758665913117699, -1.1454472222631027, -0.09397624197466384, -0.6503822466912196, 0.008655883085852913, -0.4404433589565672, -0.2620839334767402, 0.7755623889979083, -0.6624595378127414, -0.5505295444754024, 2.986129729628231, -0.6814567461026806, -0.7266576792220488, -0.8724611204948644, -0.4370177172249645, -0.3270563189427254, -0.8065591797061676, -0.4084393790158749, 0.05050132465914189, 0.08934265337427871, -0.3887153501805248, -0.18454571709136805, -0.3094319259272874, -0.3848416143425758, -0.06098313703116335, 2.1404218387855565, -0.3238760541173265, -0.19022554529161376, -0.22012305202226815, -0.6044298612018519, -0.6520336218241334, -0.0425437449415939, -0.7854278577331142, -0.9525115698835318, -0.41367359920977764, -0.09315273514500294, -0.5541340327702283, -0.02184075724394957, -0.09055891625574737, -0.4303030662183387, -0.45830477260655766, -0.25680127868471336, 2.1316034700880047, -0.3037177553107771, -0.341420317851558, -0.7966961170175247, -0.8800704472103561, -0.5329997604452533, -0.04329214396395726, -0.14438658634041138, -0.3400280638456357, 0.06050617244035202, -0.516539456643936, -0.003949419557402035, -0.6395325232446172, -1.0082755145037308, -0.7923265753254567, 1.6079625926693901, -0.6331854108331468, -0.013813019622235852, 0.0021664380718746414, -0.10357857309464986, -0.04935824589601536, -0.4329318498969638, -0.06330307810013028, -0.6193905737192265, -0.5458827566021243, -0.3102334307292689, -0.18769799733113285, -0.2546121058694798, -0.6729292065758703, -0.6713078491251081, -0.9356062292091886, -0.17976779736737672, -0.560945212450156, 0.00516985151387363, -0.4832719659606401, -0.23303484011703668, -0.1676658612822259, -0.49696686895748715, -0.07667728827753223, 1.3309017289040452, -0.5138996662952754, -0.5781770814719861, -0.14267208622760247, -0.1760330886895491, -0.36950648408598086, -0.5990482301225238, -0.4313852965647719, -0.5553497285232436, 1.7809951463899707, -0.21243772505313163, -0.40407727453829734, -0.4376949776822371, 0.02912221761100647, -0.6315859260642162, -0.6252230293139015, -0.8380542599344194, -0.6881984120561301, -0.49480719234755355, 0.0246922581538592, -0.3140866481768902], "y": [0.6026980857929628, 0.9280233844252245, 0.29411402114235013, -0.2591184461646381, 0.15267660703533673, 0.379003 ...

# %%
np.cov(dfz)
# Out:
# array([[ 0.07189259,  0.18484345,  0.10033153, ..., -0.13979329,
#         -0.11656422, -0.25802146],
#        [ 0.18484345,  0.56696531,  0.31979739, ..., -0.49308764,
#         -0.41370493, -0.84078738],
#        [ 0.10033153,  0.31979739,  0.33616544, ..., -0.23419778,
#         -0.24856004, -0.58491148],
#        ...,
#        [-0.13979329, -0.49308764, -0.23419778, ...,  0.52061273,
#          0.51347613,  0.78240127],
#        [-0.11656422, -0.41370493, -0.24856004, ...,  0.51347613,
#          0.74292304,  0.83449074],
#        [-0.25802146, -0.84078738, -0.58491148, ...,  0.78240127,
#          0.83449074,  1.42803637]])

# %%
zumap = umap.UMAP(n_neighbors=20,
                      min_dist=.2,
                      metric='euclidean').fit_transform(dfz)
fig = sns.scatterplot(zumap[:,0], zumap[:,1])
fig.set_title('ZIFA-UMAP (5 dim): genes with fewer than 95% zeros')
#fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# Text(0.5, 1.0, 'ZIFA-UMAP (5 dim): genes with fewer than 95% zeros')

# %%
fig = sns.scatterplot(zumap[:,0], zumap[:,1], hue = dfz.index)
fig.set_title('ZIFA-UMAP (5 dim): genes with fewer than 95% zeros; cell type labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
zumapbest = umap.UMAP(n_neighbors=20,
                      min_dist=.2,
                      metric='euclidean').fit_transform(dfzbest)
fig = sns.scatterplot(zumapbest[:,0], zumapbest[:,1])
fig.set_title('ZIFA-UMAP (5 dim): 100 kbest genes')
#fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# Text(0.5, 1.0, 'ZIFA-UMAP (5 dim): 100 kbest genes')

# %%
fig = sns.scatterplot(zumapbest[:,0], zumapbest[:,1], hue = dfzbest.index)
fig.set_title('ZIFA-UMAP (5 dim): 100 kbest genes; cell type labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
gmm = GaussianMixture(n_components = 6)
gmm.fit(dfz)
cluster = gmm.fit_predict(dfz)

# %%
fig = sns.scatterplot(zcomps[:,0], zcomps[:,1], hue = cluster,palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-PCA (5 dim): 100 kbest genes; GMM labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zumap[:,0], zumap[:,1], hue = cluster,palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-UMAP (5 dim): genes with fewer than 95% zeros; GMM labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
gmmbest = GaussianMixture(n_components = 6)
gmmbest.fit(dfzbest)
clusterbest = gmmbest.fit_predict(dfzbest)

# %%
fig = sns.scatterplot(zcompsbest[:,0], zcompsbest[:,1], hue = clusterbest,palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-PCA (5 dim): 100 kbest genes; GMM labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zumapbest[:,0], zumapbest[:,1], hue = clusterbest, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-UMAP (5 dim): 100 kbest genes; cell type labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
km = KMeans(n_clusters = 6, random_state=42)
kmdata = km.fit_transform(dfz)
kpred = km.fit_predict(dfz)

# %%
fig = sns.scatterplot(kmdata[:,0], kmdata[:,1], hue = dfz.index)
fig.set_title('ZIFA-k-means (5 dim): genes with fewer than 95% zeros; cell type labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(kmdata[:,0], kmdata[:, 1], hue = kpred, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-k-means (5 dim): genes with fewer than 95% zeros; k-means clusters labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zcomps[:,0], zcomps[:,1], hue = kpred, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-PCA (5 dim): genes with fewer than 95% zeros; k-means clusters labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zumap[:,0], zumap[:,1], hue = kpred,palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-UMAP (5 dim): genes with fewer than 95% zeros; k-means cluster labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
kmbest = KMeans(n_clusters = 6, random_state=42)
kmdatabest = kmbest.fit_transform(dfzbest)
kpredbest = kmbest.fit_predict(dfzbest)

# %%
fig = sns.scatterplot(kmdatabest[:,0], kmdatabest[:,1], hue = dfzbest.index)
fig.set_title('ZIFA-k-means (5 dim): 100 kbest genes; cell type labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(kmdatabest[:,0], kmdatabest[:, 1], hue = kpredbest, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-k-means (5 dim): 100 kbest genes; k-means clusters labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zcompsbest[:,0], zcompsbest[:,1], hue = kpredbest, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-PCA (5 dim): 100 kbest genes; k-means clusters labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zumapbest[:,0], zumapbest[:,1], hue = kpredbest, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-UMAP (5 dim): 100 kbest genes; k-means cluster labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
agg = AgglomerativeClustering(n_clusters = 6, affinity='euclidean',linkage = 'complete')
aggdata = agg.fit(dfz)
aggpred = aggdata.labels_

# %%
fig = sns.scatterplot(zumap[:,0], zumap[:,1], hue = aggpred, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-UMAP (5 dim): genes with fewer than 95% zeros; k-means cluster labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
aggbest = AgglomerativeClustering(n_clusters = 6, affinity='euclidean',linkage = 'complete')
aggbestdata = aggbest.fit(dfzbest)
aggpredbest = aggbestdata.labels_

# %%
fig = sns.scatterplot(zumapbest[:,0], zumapbest[:,1], hue = aggpredbest, palette =['b', 'r', 'g', 'm', 'y', 'c'])
fig.set_title('ZIFA-UMAP (5 dim): 100 kbest genes; k-means cluster labels')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
dendrogram(linkage(dfz, method = 'ward'))
plt.show()

# %%
dfcelltypes = pd.DataFrame(df2.mean(), columns = ['All cell average'])
dfcelltypes['youngLTHSC'] = df2[df2.index == 'youngLTHSC'].mean()
dfcelltypes['youngSTHSC'] = df2[df2.index == 'youngSTHSC'].mean()
dfcelltypes['youngMPP'] = df2[df2.index == 'youngMPP'].mean()
dfcelltypes['oldLTHSC'] = df2[df2.index == 'oldLTHSC'].mean()
dfcelltypes['oldSTHSC'] = df2[df2.index == 'oldSTHSC'].mean()
dfcelltypes['oldMPP'] = df2[df2.index == 'oldMPP'].mean()

# %%
dfcellbroad = pd.DataFrame(df2.mean(), columns = ['All cell average'])
dfcellbroad['HSC'] = df2[df2.index.str.contains('HSC')].mean()
dfcellbroad['MPP'] = df2[df2.index.str.contains('MPP')].mean()
dfcellbroad['HSC/MPP'] = dfcellbroad['HSC']/dfcellbroad['MPP']
#dfcellbroad.sort_values(by = ['HSC/MPP','HSC','MPP'], ascending = False).head(25000)
