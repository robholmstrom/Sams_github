# %% [markdown]
# # Investigation of blood stem cell biology through unsupervised approaches

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import umap
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.mixture import GaussianMixture
from sklearn.feature_selection import SelectKBest, f_classif

# %%
df = pd.read_csv('/Users/robholmstrom/OneDrive/Gitrepos/nonrepo_files/GSE59114.csv', header = 1)
df1 = df.T
df1.columns = df1.loc['Gene Symbol'].reset_index()
df1 = df1.drop(['Gene Symbol', 'UCSC transcripts'])
df1.columns = [x[1] for x in df1.columns]
df1.columns = df1.columns.str.replace("'", "")

# %% [markdown]
# # Dataset description

# %% [markdown]
# ## Bone marrow isolation of stem cells
#
# ~10 old mice
# ~10 young mice
#
# ~ 200 per cell type:
#     1. Longterm HSC--young
#     2. Longterm HSC--old
#
#     3. Longterm HSC--young
#     4. Longterm HSC--old
#
#     5. Longterm HSC--young
#     6. Longterm HSC--old
#
# ~1200 cells (samples)
#
# ~8000 genes analyzed (dimensions)

# %%
df1.head(5)
# Out:
#                 Npl Qk    Park2   Agpat4  Slc22a3 uc008akv.1     Airn  \
# young_LT_HSC_2    0  0  2.66676        0        0          0        0
# young_LT_HSC_6    0  0        0        0        0          0        0
# young_LT_HSC_8    0  0  6.33181        0        0          0  3.93546
# young_LT_HSC_9    0  0        0        0        0          0        0
# young_LT_HSC_10   0  0        0  2.15704  6.61412          0        0
#
#                   Mrpl18     Tcp1   Rnasel  ...      Ezr   Rsph3b   Tagap1  \
# young_LT_HSC_2   9.25531        0        0  ...  7.89221        0  2.52356
# young_LT_HSC_6         0  10.5123  3.63343  ...        0  8.29825        0
# young_LT_HSC_8         0        0  7.18398  ...   8.6596  7.70736  7.17562
# young_LT_HSC_9   8.79727        0        0  ...  2.31325        3  7.84587
# young_LT_HSC_10  8.83564  6.11541  8.17223  ...        0  8.12138  8.26651
#
#                 Rnaset2b     Dhx9   Rsph3a Rnaset2a  Fgfr1op     Mpc1   Sft2d1
# ...

# %% [markdown]
# ## Problem :
# "Dimensionality reduction of such high-dimensional data
# sets is essential for visualization and analysis, but single-cell RNA-seq data are challenging for classical dimensionalityreduction
# methods because of the prevalence of dropout events, which lead to zero-inflated data."

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solutions:
# 1. Remove high zero fraction genes from analysis (e.g. keep genes with less than 40%
#
# 2. Preprocess data by dimension reduction method that adjusts for zero inflation

# %% [markdown]
# ## PCA with all genes and no preprocessing:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## UMAP with all genes and no preprocessing:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# "Factor analysis is a statistical method used to describe variability among observed, correlated variables in terms of a potentially lower number of unobserved variables called factors. For example, it is possible that variations in six observed variables mainly reflect the variations in two unobserved variables." Wikipedia

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# ## PCA after ZIFA

# %% [markdown]
# <div>
# <img src=ttachment:image.png

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## UMAP after ZIFA

# %% [markdown]
# ![image.png](attachment:image.png)
