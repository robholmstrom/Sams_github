# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import numpy as np
import umap
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.mixture import GaussianMixture
from sklearn.feature_selection import SelectKBest, f_classif
import pylab
import scipy
import sklearn
import time
import seaborn as sns
from mpl_toolkits import mplot3d 
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px
import plotly.graph_objs as go

# %%
pd.set_option("display.max_rows", 250000)

# %%
df = pd.read_csv('/Users/robholmstrom/OneDrive/Gitrepos/nonrepo_files/GSE59114.csv', header = 1)
df1 = df.T
df1.columns = df1.loc['Gene Symbol'].reset_index()
df1 = df1.drop(['Gene Symbol', 'UCSC transcripts'])
df1.columns = [x[1] for x in df1.columns]
df1.columns = df1.columns.str.replace("'", "")
df1.shape
# Out:
# (1434, 8422)

# %% [markdown]
# Itgam, Ly6g, Ptprc, Cd3e, Ly76, Kit, Ly6a, Cd48, Slamf1

# %%
import re
df1_1 = df1[~df1.index.str.contains('biol_replicate')]
df1_1 = df1_1.drop(['\'Young LT-HSC\'','\'Young ST-HSC\'', '\'Young MPP\'','\'Old LT-HSC\'', '\'Old ST-HSC\'','Old MPP\''])
df1_1 = df1_1.drop(['Itgam', 'Ptprc', 'Kit', 'Ly6a', 'Cd48', 'Slamf1'], axis = 1)

# %%
df1_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1058 entries, young_LT_HSC_2 to old_MPP_168
# Columns: 8416 entries, Npl to Sft2d1
# dtypes: object(8416)
# memory usage: 67.9+ MB

# %%
df1_1.index = df1_1.index.str.replace(r'[^a-zA-Z]', '')

print((df1_1.columns).shape)
print(np.unique(df1_1.index))
# Out:
# (8416,)
# ['oldLTHSC' 'oldMPP' 'oldSTHSC' 'youngLTHSC' 'youngMPP' 'youngSTHSC']

# %%
df1_1dup = df1_1[df1_1.loc[:,df1_1.columns.duplicated()].columns]

# %%
dupcols = np.unique(df1_1dup.columns)
dupcols
# Out:
# array(['Abcg2', 'Arih1', 'Atf7ip', 'Atrip', 'Brwd1', 'Cbx1', 'Ccnd3',
#        'Cdk6', 'Celf1', 'Commd1', 'Csnk1a1', 'Ctse', 'Dnajb6', 'Eci2',
#        'Eif1ax', 'Fgd4', 'Fus', 'G3bp1', 'Glod4', 'Gm10598', 'Gm13215',
#        'Hjurp', 'Ikbkb', 'Ing4', 'Itga4', 'Itga6', 'Kansl2', 'Lcor',
#        'Lrrc29', 'Luc7l2', 'Mafg', 'Mecom', 'Mob1a', 'Mtcp1', 'Nagk',
#        'Ndufa3', 'Pafah1b1', 'Patz1', 'Pcif1', 'Pik3ip1', 'Psme4', 'Pten',
#        'Ramp2', 'Rpl24', 'Rspry1', 'Satb1', 'Smarcc2', 'Srcap', 'Srsf10',
#        'Sugp2', 'Taf9', 'Tex261', 'Tmem167b', 'Tmem181b-ps', 'Trappc9',
#        'Trim30b', 'U2af1l4', 'Utp23', 'Wwp2', 'Zbtb20', 'Zfp708',
#        'Zfp869', 'Zgpat'], dtype=object)

# %%
df1_1dupgroup = df1_1dup.groupby(df1_1dup.columns, axis=1).sum()

# %%
df1_1dupmean = pd.DataFrame()
for x in dupcols:
    df1_1dupmean[x] = df1_1dupgroup[x]/df1_1dup.columns.tolist().count(x)

# %%
# cols = []
# n = 1
# for x in df2dup.columns:
#     if x in cols:
#         cols.append(x+'.'+str(n))
#         n += 1
#     else:
#         cols.append(x)
#         n = 1

# %%
dfnodup = df1_1.loc[:,~df1_1.columns.duplicated()].drop(dupcols, axis = 1)

df2 = pd.concat([dfnodup, df1_1dupmean], axis = 1)

df2= df2.round(2)
df2.shape
# Out:
# (1058, 8351)

# %%
dfdes = df2.replace(0, np.nan).describe().T

# %%
varcols = dfdes[dfdes['std']/dfdes['mean']>.9].index
varcols
dfvar= df2[varcols]
dfvar.shape
# Out:
# (1058, 158)

# %%
genefracs = (dfvar.replace(np.nan, 0)==0).sum()/(dfvar.replace(np.nan, 0)==0).count()
passindex = genefracs[genefracs < .95]
passindex
# Out:
# Zfp54                                          0.839319
# uc008ard.2,uc008are.2                          0.516068
# Zfp40                                          0.493384
# Lmf1                                           0.452741
# Cenpl                                          0.542533
# uc008bxp.2                                     0.796786
# Zfp955a                                        0.461248
# H2-T3                                          0.765595
# Rhag                                           0.860113
# Nme7                                           0.568053
# Xdh                                            0.447070
# Ccdc75                                         0.447070
# Slc25a46                                       0.394140
# Rab27b                                         0.793951
# Sfxn2                                          0.465028
# Pdcd11                                         0.522684
# Frmd4a                                         0.434783
# Ptges                                          0.752363
# Ttc21b                                         0.228733
# Dcaf17                                         0.523629
# Cenpf                                          0.720227
# Nsl1                                           0.452741
# Zfp408                                         0.459357
# A130010J15Rik                                  0.393195
# Rag2                                           0.851607
# Kif18a                                         0.202268
# uc007egy.1,uc007egz.1,uc007eha.1,uc007ehb.1    0.190926
# Tmem87a                                        0.563327
# Zscan29                                        0.581285
# Polr3f                                         0.262760
# Tpx2                                           0.458412
# Pofut1                                         0.564272
# E2f1                                           0.724008
# Tbl1xr1                                        0.529301
# Dbt                                            0.695652
# Agl                                            0.211720
# Dnajb14                                        0.569943
# Trmt10a                                        0.336484
# Usp45                                          0.654064
# Manea                                          0.551985
# Tgfbr1                                         0.300567
# Fktn                                           0.778828
# Acot11                                         0.591682
# Mob3c                                          0.267486
# Tie1                                           0.410208
# Zfp46                                          0.724953
# Plod1                                          0.592628
# Tas1r1                                         0.620983
# Slc35e2                                        0.206049
# Slc25a40                                       0.697543
# Klhl7                                          0.494329
# Pbld1                                          0.603025
# Ube3c                                          0.597353
# Emilin1                                        0.513233
# Jakmip1                                        0.498110
# Cd38                                           0.702268
# Sgsm1                                          0.402647
# Mvk                                            0.853497
# Slc24a6                                        0.726843
# Oas3                                           0.157845
# uc008zie.1,uc008zif.1                          0.698488
# Acad10                                         0.685255
# Anapc7                                         0.336484
# uc009abd.2,uc009abe.2                          0.709830
# C330006K01Rik                                  0.794896
# Rbak                                           0.775992
# Lrrc61                                         0.824197
# Gimap3                                         0.603025
# Vopp1                                          0.656900
# Hpgds                                          0.633270
# Il18r1                                         0.664461
# Cand2                                          0.438563
# Il18rap                                        0.527410
# Zfp248                                         0.749527
# D6Wsu163e                                      0.640832
# Clec7a                                         0.947070
# Zfp444                                         0.585066
# Mill2                                          0.771267
# Gm4767                                         0.345936
# uc011xjm.1                                     0.507561
# Cd33                                           0.754253
# Dhdh                                           0.562382
# Nav2                                           0.562382
# Lins                                           0.615312
# Pik3c2a                                        0.519849
# Lyrm1                                          0.731569
# Gga2                                           0.411153
# Tmco3                                          0.507561
# Cln8                                           0.467864
# Vezt                                           0.547259
# Zfp963                                         0.543478
# Ces2g                                          0.625709
# Zfp90                                          0.727788
# Terf2ip                                        0.290170
# Cdt1                                           0.414934
# Nup133                                         0.515123
# Zfp26                                          0.396030
# Zfp426                                         0.564272
# Zfp202                                         0.696597
# Ulk3                                           0.741966
# Myo1e                                          0.827977
# Sh3bgrl2                                       0.899811
# uc009qyg.1                                     0.601134
# Tmppe                                          0.237240
# Ccr2                                           0.809074
# Mtm1                                           0.400756
# Prkx                                           0.717391
# Arhgef9                                        0.896975
# B230206F22Rik                                  0.279773
# uc009uco.1,uc009ucp.1,uc009ucq.1,uc012hnx.1    0.279773
# Sytl4                                          0.626654
# Rbm41                                          0.511342
# Camk2b                                         0.804348
# Sco1                                           0.482042
# Cyb5d2                                         0.641777
# Rad51l3                                        0.169187
# Dhx40                                          0.377127
# Osbpl7                                         0.427221
# Mfsd11                                         0.401701
# Birc5                                          0.232514
# Atg9a                                          0.481096
# Pycr1                                          0.556711
# Mfsd2b                                         0.726843
# G2e3                                           0.474480
# uc007nod.1,uc007noe.1,uc011ylz.1,uc011yma.1    0.128544
# Klhdc2                                         0.474480
# Mir1906-1                                      0.809074
# Ighv1-30                                       0.410208
# Esyt2                                          0.554820
# Zfp322a                                        0.479206
# Lrrc16a                                        0.534972
# Dusp22                                         0.656900
# F13a1                                          0.723062
# Zfp874b                                        0.199433
# Zfp273                                         0.826087
# Syt15                                          0.441399
# Serpinb8                                       0.635161
# uc007urd.1                                     0.305293
# Deptor                                         0.194707
# Zfp7                                           0.265595
# uc007xdn.2,uc007xdo.2                          0.517013
# Abcd2                                          0.821361
# Slc11a2                                        0.702268
# Smug1                                          0.286389
# Pi4ka                                          0.606805
# uc007yrn.1,uc007yro.1,uc007yrp.1               0.587902
# Lpp                                            0.197543
# Trove2                                         0.390359
# BC027231                                       0.476371
# Cep97                                          0.319471
# Jam2                                           0.468809
# Itsn1                                          0.625709
# Brwd1                                          0.365784
# Rspry1                                         0.227788
# Trim30b                                        0.224953
# dtype: float64

# %%
zifavar = dfvar[passindex.index].replace(np.nan, 0)
zifavar= np.round(zifavar.astype(np.float64),4)
zifavar = np.array(zifavar)
zifavar.shape
# Out:
# (1058, 155)

# %%
from ZIFA import ZIFA
from ZIFA import block_ZIFA

# %%
start_time = time.time()
Z, model_params = block_ZIFA.fitModel(zifavar,5)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Filtering out all genes which are zero in more than 95.0% of samples. To change this, change p0_thresh.
# Warning: your Y matrix contains genes which are frequently zero. If the algorithm fails to converge, try filtering out genes which are zero more than 80 - 90% of the time, or using standard ZIFA.
# Number of blocks has been set to 1
# Running block zero-inflated factor analysis with N = 1058, D = 155, K = 5, n_blocks = 1
# Block sizes [155]
# Param change below threshold 1.000e-02 after 10 iterations
# --- 19.182281017303467 seconds ---

# %%
dfz = pd.DataFrame(Z, index = df2.index)
pcaz = PCA(n_components=3, random_state = 42)

zcomps = pcaz.fit_transform(dfz)
variance = np.insert(pcaz.explained_variance_ratio_, 0, 1)
x = [i for i in range(variance.shape[0])]

plt.plot(x, variance)

# %%
sns.scatterplot(zcomps[:,0], zcomps[:,1])
plt.show()

# %%
sns.scatterplot(zcomps[:,0], zcomps[:,1], alpha =1,hue = dfz.index, palette =['b', 'r', 'g', 'm', 'y', 'c'])
plt.show()

# %%
encoded = {'oldLTHSC':0, 'oldMPP':1, 'oldSTHSC':2, 'youngLTHSC':3, 'youngMPP':4, 'youngSTHSC':5}
cells = ['oldLTHSC' ,'oldMPP', 'oldSTHSC', 'youngLTHSC' ,'youngMPP' ,'youngSTHSC']
cell_types = [encoded.get(x, x) for x in dfz.index]
colormap = ['r', 'b', 'g', 'y', 'c', 'm']
cell_colors = [colormap[x] for x in cell_types]
dfpca = pd.DataFrame(zcomps, index = dfz.index)
dfpca
fig = px.scatter_3d(dfpca, zcomps[:,0], zcomps[:,1],zcomps[:,2], dfpca.index)
fig.update_traces(marker=dict(opacity =1, size=5,
                              line=dict(width= .1)))

fig.show()
# Out:
# <div>
#
#
#             <div id="c61df8d2-781e-44c1-9c81-a90ec3af3c24" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c61df8d2-781e-44c1-9c81-a90ec3af3c24")) {
#                     Plotly.newPlot(
#                         'c61df8d2-781e-44c1-9c81-a90ec3af3c24',
#                         [{"hovertemplate": "index=youngLTHSC<br>x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>", "legendgroup": "youngLTHSC", "marker": {"color": "#636efa", "line": {"width": 0.1}, "opacity": 1, "size": 5, "symbol": "circle"}, "mode": "markers", "name": "youngLTHSC", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.30277250747315976, -0.13981662078483104, 0.011087379039787557, -0.41807603610461047, -0.6148897993582004, -0.17382327272297773, 0.02287412715769136, -0.1149427965337564, -0.7198231476805794, -0.6770698252210625, 1.1315221478670017, -0.6192761591029495, -0.6559310464259624, -0.1804180559969427, -0.6273887854171345, -0.5694738988099131, -0.976187036527918, -0.723730462051107, -0.34794055547485797, 2.439691809695738, -0.47943816049945126, -0.561299191533493, -0.5216054210541821, 2.523325922993706, -0.8053724753351865, -0.32851813516766676, 0.36358742720800796, -0.573149983416669, -0.606548361106453, -0.6965814280299008, 0.6186508259100703, 2.174743603691033, -0.5611857290946921, -0.6093926367024738, 1.1331844987414843, -0.2734970551560218, -0.21175385794991847, 0.13276694662452931, -0.9380675150065566, -0.8275152539413421, -0.47883465767103833, -0.9109504075933501, -0.3687588487315642, -0.5489433811109001, -0.46471159553950475, -0.42649769783189884, -0.09853517390375832, -0.4122572979452916, -0.1840267755650217, -0.5046508247897581, -0.6474036346853775, -0.5142969877744119, -0.5756352951945051, -0.8277941842167581, -0.6925373294326107, -0.6945022497809475, 1.6901965064258606, -0.43578224717430775, -0.9621942855200455, -0.4205720499830284, -0.3528372773542474, -0.7859549968008499, -0.16007699417876609, -0.3134875594959112, -0.45508140745886566, -0.7846932297822159, -0.37023104561822084, -0.8850799771012323, -0.5004721833437653, -0.2197303238639339, -0.5382449475397115, -0.4171261432601366, -0.9108792781975001, -0.2518174671945914, -0.5179626037219526, -0.3417700252104852, 0.00924762732781902, 0.011712264080252052, -0.6472097798678612, -0.30223819349068837, -0.009339892481641505, -0.4562943744294998, -0.006160907459654514, -0.4364640126749483, -0.33856131262428046, -0.8366612650107281, -0.4006476244450808, -0.5684054079780109, -0.19474336793395056, -0.2217011566700892, -0.1419821032097302, -0.4259504629970743, -0.3993539069882582, 0.26591184385666905, -0.511468741138655, -0.21569829787101194, -0.41567272175341274, -0.8740481959486903, -0.5653811811401993, -0.5424980451106242, -0.5397320656404297, -0.3235696103145271, -0.4416101705460927, -0.024427632537268776, -0.9489498391719466, -0.5955564114617357, -0.09054209751489242, -0.1408215309366848, -0.552703833916119, -0.3850479405851107, -0.47184501244715493, 1.6145789292511774, -0.45437740594882636, -0.45731186855380074, -0.6074294608508821, -0.07915180709398772, -0.5924304788443869, -0.030377531493332208, -0.48647694330993646, -0.28418360668119524, -0.787791237062358, -0.09274288379919329, -0.437463214300056, -0.0703419175122723, -0.23564615044261775, -0.48643276693560933, -0.7315911275466186, -0.6847582513415069, -0.25650569105153126, -0.5932954664630183, 0.39197737233332286, -0.37406133790291135, -0.49423946591713713, -0.33196266759027176, 0.8289068442637375, -0.06846655356056476, -0.6971817966435319, -0.8715784770989767, -0.33499575753401223, -0.5037608890588315, -0.8377299598199655, 0.6830215886661583, -0.029569421457191776, -0.2124990848316817, -0.18242685548828597, -0.27735845824750055, -0.3505286908590085, -0.41506696359907136, 0.17979646450269315, -0.2930515836231767, 2.991870246512174, 0.5954033465018179, 0.0656965692741892, -0.43897472917323627, -0.6163209387617534, -0.21376588212958372, -0.8394162177103839, 0.009629064680199329, 0.06323442682424495, 0.22311578264212253, -0.6602609174707819, -0.2891775572615509, -0.45365444875120087, -0.5699833746561075, -0.16803681764313302, -0.07648247467986427, -0.41914564653272096], "y": [-0.715394516185638, -0.601570307025797, -0.05551265613517748, -0.3775531718119897, -0.5411096942938463, -0.43 ...

# %%
zumap = umap.UMAP(n_neighbors=20,
                      min_dist=.2,
                      metric='euclidean').fit_transform(dfz)
fig = sns.scatterplot(zumap[:,0], zumap[:,1])
fig.set_title('ZIFA-UMAP (5 dim): high variance genes (no zeros)')
#fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# Text(0.5, 1.0, 'ZIFA-UMAP (5 dim): high variance genes (no zeros)')

# %%
fig = sns.scatterplot(zumap[:,0], zumap[:,1], hue = dfz.index)
fig.set_title('ZIFA-UMAP (5 dim): high variance genes (no zeros); cell type labeled')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
gmm = GaussianMixture(n_components = 6)
gmm.fit(dfz)
cluster = gmm.fit_predict(dfz)

# %%
fig = sns.scatterplot(zcomps[:,0], zcomps[:,1], hue = cluster, palette = ['r', 'b', 'g', 'y', 'c', 'm'])
fig.set_title('ZIFA-PCA (5 dim): high variance genes (no zeros); GMM cluster labeled')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zumap[:,0], zumap[:,1], hue = cluster, palette = ['r', 'b', 'g', 'y', 'c', 'm'])
fig.set_title('ZIFA-UMAP (5 dim): high variance genes (no zeros); GMM cluster labeled')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
km = KMeans(n_clusters = 6, random_state=42)
kmdata = km.fit_transform(dfz)
kpred = km.fit_predict(dfz)

# %%
fig = sns.scatterplot(kmdata[:,0], kmdata[:,1], hue = dfz.index)
fig.set_title('ZIFA-k-means (5 dim): high variance genes (no zeros); cell type labeled')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(kmdata[:,0], kmdata[:, 1], hue = kpred, palette = ['r', 'b', 'g', 'y', 'c', 'm'])
fig.set_title('ZIFA-k-means (5 dim): high variance genes (no zeros); k-means cluster labeled')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig= sns.scatterplot(zcomps[:,0], zcomps[:,1], hue = kpred, palette = ['r', 'b', 'g', 'y', 'c', 'm'])
fig.set_title('ZIFA-PCA (5 dim): high variance genes (no zeros); k-means cluster labeled')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
fig = sns.scatterplot(zumap[:,0], zumap[:,1], hue = kpred, palette = ['r', 'b', 'g', 'y', 'c', 'm'])
fig.set_title('ZIFA-UMAP (5 dim): high variance genes (no zeros); k-means labeled')
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
dendrogram(linkage(dfz, method = 'ward'))
plt.show()

# %%
dfcelltypes = pd.DataFrame(df2.mean(), columns = ['All cell average'])
dfcelltypes['youngLTHSC'] = df2[df2.index == 'youngLTHSC'].mean()
dfcelltypes['youngSTHSC'] = df2[df2.index == 'youngSTHSC'].mean()
dfcelltypes['youngMPP'] = df2[df2.index == 'youngMPP'].mean()
dfcelltypes['oldLTHSC'] = df2[df2.index == 'oldLTHSC'].mean()
dfcelltypes['oldSTHSC'] = df2[df2.index == 'oldSTHSC'].mean()
dfcelltypes['oldMPP'] = df2[df2.index == 'oldMPP'].mean()

# %%
dfcellbroad = pd.DataFrame(df2.mean(), columns = ['All cell average'])
dfcellbroad['HSC'] = df2[df2.index.str.contains('HSC')].mean()
dfcellbroad['MPP'] = df2[df2.index.str.contains('MPP')].mean()
dfcellbroad['HSC/MPP'] = dfcellbroad['HSC']/dfcellbroad['MPP']
dfcellbroad.sort_values(by = ['HSC/MPP','HSC','MPP'], ascending = False).head(25000)
